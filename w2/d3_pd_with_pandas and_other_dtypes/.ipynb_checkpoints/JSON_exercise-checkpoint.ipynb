# %% [markdown]
# # JSON exercise
#
# Download the data from [**here**](https://drive.google.com/file/d/1DGaX5AVfYhmWeb15lI-MzUbSKTYSz9fQ/view?usp=sharing) and answer following questions:
# 1. Find the 10 countries with most projects
# 2. What are top 10 sectors with projects?
# 3. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 4. In 3. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
import json
import pandas as pd
import pprint

# %%
with open('world_bank_projects.json') as f:
    world_bank = json.load(f)

# %%
# pprint.pprint(world_bank)

# %%
from pandas import json_normalize  
json_normalize(world_bank).head(2)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
#
#                impagency                                       project_name  \
# 0  MINISTRY OF EDUCATION  Ethiopia General Education Quality Improvement...
# 1    MINISTRY OF FINANCE          TN: DTF Social Protection Reforms Support
#
#   mjthemecode           closingdate  ...  sector2.Percent  \
# 0        8,11  2018-07-07T00:00:00Z  ...             26.0
# 1         1,6                   NaN  ...             30.0
#
# ...

# %% [markdown]
# ### Find the 10 countries with most projects

# %%
world = pd.read_json('world_bank_projects.json')
world.head(2)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
#
#                impagency                                       project_name  \
# 0  MINISTRY OF EDUCATION  Ethiopia General Education Quality Improvement...
# 1    MINISTRY OF FINANCE          TN: DTF Social Protection Reforms Support
#
#   mjthemecode           closingdate  ...  \
# 0        8,11  2018-07-07T00:00:00Z  ...
# 1         1,6                   NaN  ...
#
#                                  majorsector_percent board_approval_month  \
# ...

# %%
active_only = world[world["projectstatusdisplay"]=="Active"]
active_countries=active_only[["countryname","_id", "projectstatusdisplay"]]
active_countries.groupby('countryname').count().sort_values(by=["projectstatusdisplay"], ascending=False).head(10)
# Out:
#                                  _id  projectstatusdisplay
# countryname
# People's Republic of China        19                    19
# Republic of Indonesia             16                    16
# Republic of India                 15                    15
# Socialist Republic of Vietnam     14                    14
# Republic of Yemen                 13                    13
# People's Republic of Bangladesh   12                    12
# Nepal                             11                    11
# Africa                            11                    11
# Islamic Republic of Pakistan       9                     9
# Republic of Mozambique             9                     9

# %%
json_normalize(world["_id"])
# Out:
#                          $oid
# 0    52b213b38594d8a2be17c780
# 1    52b213b38594d8a2be17c781
# 2    52b213b38594d8a2be17c782
# 3    52b213b38594d8a2be17c783
# 4    52b213b38594d8a2be17c784
# ..                        ...
# 495  52b213b38594d8a2be17c96f
# 496  52b213b38594d8a2be17c970
# 497  52b213b38594d8a2be17c971
# 498  52b213b38594d8a2be17c972
# 499  52b213b38594d8a2be17c973
#
# [500 rows x 1 columns]

# %%
# 'countryname'
# json_normalize(data=world_bank, record_path='project_name', meta=["countryshortname"])

# %%
# this is the way to do this
a=world['countryshortname'].value_counts()
country=pd.DataFrame(a)
country.head(10)
# Out:
#                     countryshortname
# China                             19
# Indonesia                         19
# Vietnam                           17
# India                             16
# Yemen, Republic of                13
# Nepal                             12
# Morocco                           12
# Bangladesh                        12
# Africa                            11
# Mozambique                        11

# %% [markdown]
# ## What are top 10 sectors with projects?

# %%
json_normalize(world['sector'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-15eb572f8166> in <module>
# ----> 1 json_normalize(world['sector'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     258
#     259     if record_path is None:
# --> 260         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     261             # naive normalization, this is idempotent for flat records
#     262             # and potentially will inflate the data considerably for
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     258
#     259     if record_path is None:
# --> 260         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...

# %%
a = world['sector'].value_counts()
sector=pd.DataFrame(a)
sector=pd.DataFrame(sector)
sector.hear(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0d18df32cd2e> in <module>
# ----> 1 a = world['sector'].value_counts()
#       2 sector=pd.DataFrame(a)
#       3 sector=pd.DataFrame(sector)
#       4 sector.hear(10)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#    1236         dtype: int64
#    1237         """
# -> 1238         result = value_counts(
#    1239             self,
#    1240             sort=sort,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     721
#     722         else:
# --> 723             keys, counts = _value_counts_arraylike(values, dropna)
#     724
#     725             result = Series(counts, index=keys, name=name)
#
# ...

# %%
pd.DataFrame(json_normalize(world['sector']).stack())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-9a543f680910> in <module>
# ----> 1 pd.DataFrame(json_normalize(world['sector']).stack())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     258
#     259     if record_path is None:
# --> 260         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     261             # naive normalization, this is idempotent for flat records
#     262             # and potentially will inflate the data considerably for
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     258
#     259     if record_path is None:
# --> 260         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...

# %% [markdown]
# ## Find the top 10 major project themes (using column 'mjtheme_namecode')

# %%
json_normalize(world_bank).head(2)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
#
#                impagency                                       project_name  \
# 0  MINISTRY OF EDUCATION  Ethiopia General Education Quality Improvement...
# 1    MINISTRY OF FINANCE          TN: DTF Social Protection Reforms Support
#
#   mjthemecode           closingdate  ...  sector2.Percent  \
# 0        8,11  2018-07-07T00:00:00Z  ...             26.0
# 1         1,6                   NaN  ...             30.0
#
# ...

# %%
json_normalize(data=world_bank, record_path='mjtheme_namecode').groupby("name").count().sort_values(by=["code"],ascending =False)
# Out:
#                                               code
# name
# Environment and natural resources management   223
# Rural development                              202
# Human development                              197
# Public sector governance                       184
# Social protection and risk management          158
# Financial and private sector development       130
#                                                122
# Social dev/gender/inclusion                    119
# Trade and integration                           72
# Urban development                               47
# Economic management                             33
# Rule of law                                     12

# %% [markdown]
# ## above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in

# %%
json_normalize(data=world_bank, record_path='mjtheme_namecode')
# Out:
#      code                                      name
# 0       8                         Human development
# 1      11
# 2       1                       Economic management
# 3       6     Social protection and risk management
# 4       5                     Trade and integration
# ...   ...                                       ...
# 1494   10                         Rural development
# 1495    9                         Urban development
# 1496    8                         Human development
# 1497    5                     Trade and integration
# 1498    4  Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
# json_normalize(data=world_bank, record_path='mjtheme_namecode').fillna(value='filler')

# %%
def fillempty(x):
    for y in['name']:
        if y == "":

# %%
empty_df = json_normalize(data=world_bank, record_path='mjtheme_namecode')

# %%
type(empty_df)
# Out:
# pandas.core.frame.DataFrame

# %%
with open('world_bank_projects.json') as f:
    thejason = json.load(f)
a = json_normalize(data=thejason, record_path='mjtheme_namecode')
b=a[a["name"]==""]
#print(a[a["code"]=='11'])
b["code"]
thelist=b["code"].values.tolist()
print(thelist)
c=a[a["code"].isin(thelist)]
c[c["name"]!=''].drop_duplicates()

# %%
# empjty_df = json_normalize(data=world_bank, record_path='mjtheme_namecode').dropna()

# %%
# my_filter = empty_df['name']== ""
# empty_values = empty_df[my_filter]

# for i in range(len(empty_values)):
#         empty_values['name'] = 'empty'

# %%
# df.loc[(df.Event == 'Dance'),'Event']='Hip-Hop'
# df

# %%
empty_df.loc[(empty_df.name == ''), 'name'] = 'empty'

# %%
empty_df
# Out:
#      code                                      name
# 0       8                         Human development
# 1       0                                     empty
# 2       1                       Economic management
# 3       6     Social protection and risk management
# 4       5                     Trade and integration
# ...   ...                                       ...
# 1494   10                         Rural development
# 1495    9                         Urban development
# 1496    8                         Human development
# 1497    5                     Trade and integration
# 1498    4  Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
theme = json_normalize(data=world_bank, record_path='mjtheme_namecode').groupby(['code', 'name'])
# pd.DataFrame(theme)
# json_normalize(theme[["code"],""])

# %%
b["code"]
thelist=b["code"].values.tolist()
thelist

# %%
filter = empty_df["code", "name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('code', 'name')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-91661cb711dc> in <module>
# ...

# %%
# empty_df.loc[(empty_df.name == 'empty'), 'code'] = 0

# %%
# empty_df = json_normalize(data=world_bank, record_path='mjtheme_namecode')

# %%
dict_4 = {1:"Economic management", 2:"Economic management", 3:"Rule of law", 4:"Financial and private sector development",
          5:"Trade and integration", 6:"Social protection and risk management", 7: "Social dev/gender/inclusion", 8: "Human development",
          9:"Urban development",10:"Rural development", 11:"Environment and natural resources management"
         }



# df_theme_namecode['name'] = df_theme_namecode['code'].apply(lambda x:dict_4.get(int(x)))

# %%
dict_4
# Out:
# {1: 'Economic management',
#  2: 'Economic management',
#  3: 'Rule of law',
#  4: 'Financial and private sector development',
#  5: 'Trade and integration',
#  6: 'Social protection and risk management',
#  7: 'Social dev/gender/inclusion',
#  8: 'Human development',
#  9: 'Urban development',
#  10: 'Rural development',
#  11: 'Environment and natural resources management'}

# %%
empty_df['name'] = empty_df['code'].apply(lambda x:dict_4.get(int(x)))

# %%
# theme1 = json_normalize(world_bank, record_path='mjtheme_namecode').groupby([ 'code'])  #df groupby object
# theme11 = theme1.count()  # use count and becomes a df

# theme2 = json_normalize(world_bank, record_path='mjtheme_namecode').groupby([ 'code','name'])
# theme22 = theme2.count()

# theme3 = theme22.join(theme11, on='code')
# theme3
# Out:
#                                                    name
# code name
# 1                                                    38
#      Economic management                             38
# 10                                                  216
#      Rural development                              216
# 11                                                  250
#      Environment and natural resources management   250
# 2                                                   199
#      Public sector governance                       199
# 3                                                    15
#      Rule of law                                     15
# 4                                                   146
#      Financial and private sector development       146
# 5                                                    77
#      Trade and integration                           77
# 6                                                   168
#      Social protection and risk management          168
# ...
