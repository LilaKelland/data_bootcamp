# %% [markdown]
# ## Decomposition Exercise

# %%
# import pandas
import pandas as pd

# import statsmodels.api as sm
import statsmodels.api as sm

# import matplotlib
import matplotlib.pyplot as plt

# %%
# load data
data = sm.datasets.co2.load_pandas()
co2 = data.data

# %% [markdown]
# * print the top 5 rows

# %%
co2.head(5)
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4

# %% [markdown]
# * Resample the time series using monthly averages and store the new time series as a Series `y`.

# %%
y = co2.groupby(co2.index.month).mean()
y
# Out:
#            co2
# 1   339.779787
# 2   341.091617
# 3   341.638587
# 4   342.092308
# 5   343.132086
# 6   342.641989
# 7   340.608854
# 8   338.698947
# 9   337.496739
# 10  337.205236
# 11  338.208649
# 12  339.409794

# %% [markdown]
# * print the top 5 rows of 'y'

# %%
# see above

# %% [markdown]
# * check for missing values

# %%
co2.isna().sum()
# Out:
# co2    59
# dtype: int64

# %%
# NA ffil does't deal with missing values?
co2.fillna(method='ffill', inplace =True)

# %% [markdown]
# * replace missing values with last available value
#
#
#     - Example: If Feb 2010 is missing, use the value from Jan 2010.

# %%
# co2 = co2.asfreq('M', method='ffill')
# co2.isna().sum()
# Out:
# co2    15
# dtype: int64

# %%
co2.isna().sum()
# Out:
# co2    0
# dtype: int64

# %%
# Out:
# ['co2']

# %% [markdown]
# * plot the time series `y`

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

y.plot();

# %% [markdown]
# * Apply and plot the following:
#
#
#     1. additive seasonal decomposition
#     2. multiplicative seasonal decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
series = co2
result = seasonal_decompose(series, model='additive')
result.plot()
pyplot.show()

# %%
from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = co2
result = seasonal_decompose(series, model='multiplicative', period=12)
result.plot()
pyplot.show()
