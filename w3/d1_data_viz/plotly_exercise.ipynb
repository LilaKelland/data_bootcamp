# %% [markdown]
# ## Plotly Assignment
#
# **Note**: For some of you, plotly go does not display at all in Jupyter Labs. It is a known bug with plotly. If you are using Jupyter Labs for this assignment and the plots are not showing, please switch to Jupyter Notebooks or Google Collab to complete this exercise.

# %%
# import plotly graph objects
import plotly.graph_objs as go

# import pandas
import pandas as pd
import numpy as np

# %% [markdown]
# ### Task 1: Create a scatterplot with a 1000 random data points.
#
# - x-axis values should come from a normal distribution using np.random.randn(1000)
#
# - y-axis values should come from a uniform distribution over [0,1) using np.random.rand(1000)

# %%
# obtain the x and y values:

random_x = np.random.randn(1000)
random_y = np.random.rand(1000)

# %%
# define a data variable
data = [go.Scatter(
            x = random_x,
            y = random_y,
            mode = 'markers',
        )]

# %%
# define the layout, include a title and axis labels
# create the layout 
layout = go.Layout(
    title = 'Random Data Scatterplot',
        
    xaxis = dict(title = 'random_x'), # x-axis label
    yaxis = dict(title = 'random_y'), # y-axis label
#     hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# Create a fig from the data and layout. Then plot the fig
# create the figure
fig = go.Figure(data=data, layout=layout)
# fig.update_layout(
#     title={
#         'text': "Scatter Plot of Randomness ",
#         'y':0.25,
#         'x':0.5,
#         'xanchor': 'center',
#         'yanchor': 'top'})
fig.show()

# %% [markdown]
# -------------
# ### Task 2: Create a stacked bar chart with the data in the link below.
#
# **Note** that the questions appear in the index and should be used for the x-axis, while the responses appear as column labels.
#
# Stretch Task: Create a horizontal bar chart! Use this documentation [here](https://plot.ly/python/horizontal-bar-charts/) for help.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv',index_col=0)

# %%
df.keys()
# Out:
# Index(['Strongly Agree', 'Somewhat Agree', 'Neutral', 'Somewhat Disagree',
#        'Strongly Disagree'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Strongly Agree', 'Somewhat Agree', 'Neutral', 'Somewhat Disagree',
#        'Strongly Disagree'],
#       dtype='object')

# %%
df2 =df.copy()

# %%
df2['Question'] = df2.index

# %%
df.count()
# Out:
# Strongly Agree       3
# Somewhat Agree       3
# Neutral              3
# Somewhat Disagree    3
# Strongly Disagree    3
# dtype: int64

# %%
df2
# Out:
#             Strongly Agree  Somewhat Agree  Neutral  Somewhat Disagree  \
# Question 1            0.45            0.25     0.10               0.12
# Question 2            0.12            0.07     0.48               0.18
# Question 3            0.05            0.22     0.19               0.23
#
#             Strongly Disagree    Question
# Question 1               0.08  Question 1
# Question 2               0.15  Question 2
# Question 3               0.31  Question 3

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[
    go.Bar(name='Strongly Agree', x=df2.Question, y=df2['Strongly Agree']),
    go.Bar(name='Somewhat Agree', x=df2.Question, y=df2['Somewhat Agree']),
    go.Bar(name='Neutral', x=df2.Question, y=df2['Neutral']),
    go.Bar(name='Somewhat Disagree', x=df2.Question, y=df2['Somewhat Disagree']),
    go.Bar(name='Strongly Disagree', x=df2.Question, y=df2['Strongly Disagree'])
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()

# %%
fig = go.Figure(data=[
    go.Bar(name='Strongly Agree', x=df2.Question, y=df2['Strongly Agree']),
    go.Bar(name='Somewhat Agree', x=df2.Question, y=df2['Somewhat Agree']),
    go.Bar(name='Neutral', x=df2.Question, y=df2['Neutral']),
    go.Bar(name='Somewhat Disagree', x=df2.Question, y=df2['Somewhat Disagree']),
    go.Bar(name='Strongly Disagree', x=df2.Question, y=df2['Strongly Disagree'])
])

# %%
data = []
for i in range(len(df2.columns)-1):
    print(df2.columns[i].astype(str), x=df2.Question, df2.columns.iloc[i])
#     data[i] = go.Bar(name=df2.columns[i].astype(str), x=df2.Question, y=df2.columns[i])
# Out:
#   File "<ipython-input-182-2421c7592579>", line 3
#     print(df2.columns[i].astype(str), x=df2.Question, df2.columns.iloc[i])
#                                                       ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# -------------
# ### Task 3: Create a histogram that plots the `length` field from dataset below. Set the range from 0 to 1, with a bin size of 0.02.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv')

# %%
df.keys()
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#        'viscera_weight', 'shell_weight', 'rings'],
#       dtype='object')

# %%
df.max()
# Out:
# sex                    M
# length             0.815
# diameter            0.65
# height              1.13
# whole_weight      2.8255
# shucked_weight     1.488
# viscera_weight      0.76
# shell_weight       1.005
# rings                 29
# dtype: object

# %%
df.head()
# Out:
#   sex  length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell_weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv') 

# data = go.Histogram(x=df.length, nbinsx=5)
# data = go.Histogram(x=df.length, xbins.size=0.02, xbins.start=0, xbins.end=1,)
data = go.Histogram(
            x=df.length,  
            xbins=dict(start=0, end=1, size=0.02)
        )

layout = go.Layout(
    title = "Abalone Length",
    xaxis = dict(title = 'length'), # x-axis label
    yaxis = dict(title = 'count') # y-axis label
)
fig = go.Figure(data=data, layout=layout)
# fig = go.Figure(data=go.Histogram(x=df.length, xbins=dict(start=0, end=1, size=0.02)), layout=layout)
fig.show()
