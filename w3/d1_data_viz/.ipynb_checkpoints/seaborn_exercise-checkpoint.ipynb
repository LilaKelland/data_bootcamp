# %% [markdown]
# ## Seaborn Assignment

# %%
# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv',sep=',')
df.drop('#',axis=1,inplace=True)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Task 1: Plot a regression line between attack and defense.

# %%
sns.lmplot(x='Attack', y='Defense', data = df)
plt.show()

# %% [markdown]
# ### Task 2: Plot a regression line between attack and defense while displaying a distinction between the different generations.

# %%
sns.lmplot(x='Attack', y='Defense', data = df, hue = 'Generation')
plt.show()

# %% [markdown]
# ### Task 3: Make a boxplot for each feature of dataframe (without Generation and Legendary features) in one plot.

# %%
iris = sns.load_dataset("iris")
ax = sns.boxplot(data=iris, orient="h", palette="Set2")

# %%
plt.subplot(1,2,1)
sns.boxplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
box_data = df[['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed']] 
# ax = sns.boxplot(data=df, orient="h", palette="Set2")
# plt.title('Pokemon Box Plot')
plt.figure(figsize=(16,8))
ax = sns.boxplot(data=box_data)

# %% [markdown]
# ### Task 4: Plot a correlation heatmap of the pokemon dataframe (not including the features Generation and Legendary).

# %%
heat_data = df[['Total','HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed']] 

heat_data_corr = heat_data.corr()

sns.heatmap(heat_data_corr)
plt.title('Pokemon Heat Map')
plt.show()

# %%
# # plot the correlations
# sns.heatmap(df_corr)
# plt.title('Correlation plot')
# plt.show()

heat_data = df[['HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed']] 

heat_data_corr = heat_data.corr()

# fig, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(heat_data_corr)
plt.title('Correlation Pokemon')
plt.show()
