# %%
import pandas as pd

# %% [markdown]
# ### Download the data and load it to Pandas.
#
# You can find them [here](https://drive.google.com/file/d/1NY6cmF9Shjw-dD7BD6bNmfcIVz-kQcFR/view?usp=sharing).

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### Using groupby(), count the number of films that have been released in each decade in the history of cinema.

# %%
titles['decades'] = titles['year'] - (titles['year']%10)
titles[['decades']].groupby('decades').size()
# Out:
# decades
# 1890        3
# 1900       37
# 1910     6512
# 1920     8797
# 1930    10097
# 1940     8576
# 1950    12711
# 1960    17515
# 1970    18714
# 1980    20243
# 1990    22225
# 2000    38713
# 2010    67977
# 2020      210
# dtype: int64

# %% [markdown]
# ### Use groupby() count the number of "Hamlet" films made in each decade.

# %%
titles['decades'] = titles['year'] - (titles['year']%10)
my_filter = titles['title'] == 'Hamlet'
hamlet_films = titles[my_filter]
hamlet_films
hamlet_films[['decades']].groupby('decades').size()
# Out:
# decades
# 1910    3
# 1920    1
# 1940    1
# 1950    1
# 1960    2
# 1970    2
# 1980    1
# 1990    2
# 2000    2
# 2010    3
# dtype: int64

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
my_filter = ((cast['n'] == 1) & ((cast['year'] - (cast['year']%10)) == 1950))
leading = cast[my_filter]
leading[['type', 'n']].groupby('type').size()
# Out:
# type
# actor      6616
# actress    2965
# dtype: int64

# %%
cast
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3634462                           Foxtrot  1988            Lilja ??risd?ttir
# 3634463  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3634464                         Skammdegi  1985           Dalla ??r?ard?ttir
# 3634465                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3634466                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
#             type                character     n
# 0          actor                  Buffy 4   NaN
# 1          actor                   Guests  22.0
# 2          actor          Bobby Riggs Fan  10.0
# 3          actor          2002 Dodger Fan   NaN
# 4          actor  1988 Opera House Patron   NaN
# ...          ...                      ...   ...
# 3634462  actress                     D?ra  24.0
# 3634463  actress             Woman in Bus  26.0
# 3634464  actress            Hj?krunarkona   9.0
# 3634465  actress   Afgr.dama ? bens?nst??  17.0
# 3634466  actress        Pensionatv?rtinde   NaN
#
# [3634467 rows x 6 columns]

# %% [markdown]
# ### In the 1950s taken as a whole, how many total roles were available to actors, and how many to actresses, for each "n" number 1 through 5?

# %%
my_filter = (((cast['year'] - (cast['year']%10)) == 1950) & (cast['n'] <6))
leading = cast[my_filter]
leading[['type', 'n']].groupby(by =['type', 'n']).size()
# Out:
# type     n
# actor    1.0    6616
#          2.0    4564
#          3.0    5587
#          4.0    5594
#          5.0    5611
# actress  1.0    2965
#          2.0    4556
#          3.0    3148
#          4.0    2849
#          5.0    2544
# dtype: int64

# %% [markdown]
# ### Use groupby() to determine how many roles are listed for each of the Pink Panther movies.

# %%
my_filter= (cast['title'].str.contains("Pink Panther"))
pink_panther = cast[my_filter]

pink_panther[['title','character']].groupby(by=['title']).count()
# cast['title']
# Out:
#                                 character
# title
# Curse of the Pink Panther              67
# Revenge of the Pink Panther            64
# Son of the Pink Panther                46
# The Pink Panther                      111
# The Pink Panther 2                     84
# The Pink Panther Strikes Again         68
# The Return of the Pink Panther         30
# Trail of the Pink Panther              41

# %% [markdown]
# ### List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
frank = cast[cast['name'] =='Frank Oz']
frank
frank_roles = frank[['title', 'character','year']].groupby(['title','year'], as_index=False).count()
my_filter = frank_roles['character'] >=2
result = frank_roles[my_filter].sort_index()

result
# Out:
#                                    title  year  character
# 0         An American Werewolf in London  1981          2
# 2                       Follow That Bird  1985          3
# 7                 Muppet Treasure Island  1996          4
# 8                     Muppets from Space  1999          4
# 17  The Adventures of Elmo in Grouchland  1999          3
# 19                      The Dark Crystal  1982          2
# 20                The Great Muppet Caper  1981          6
# 21            The Muppet Christmas Carol  1992          7
# 22                      The Muppet Movie  1979          8
# 23            The Muppets Take Manhattan  1984          7

# %% [markdown]
# ### List each of the characters that Frank Oz has portrayed at least twice.

# %%
cast.head(2)
# Out:
#              title  year      name   type character     n
# 0   Closet Monster  2015  Buffy #1  actor   Buffy 4   NaN
# 1  Suuri illusioni  1985    Homo $  actor    Guests  22.0

# %%
franks_movies = pd.merge(result, cast, how = 'inner', on='title')

# %%
franker =franks_movies[franks_movies['name'] =='Frank Oz']

# %%
franker[['title','character_y']]
# frank[['title', 'character','year']]
# franker.head(2)
# Out:
#                                     title  \
# 38         An American Werewolf in London
# 39         An American Werewolf in London
# 105                      Follow That Bird
# 106                      Follow That Bird
# 107                      Follow That Bird
# 224                Muppet Treasure Island
# 225                Muppet Treasure Island
# 226                Muppet Treasure Island
# 227                Muppet Treasure Island
# 323                    Muppets from Space
# 324                    Muppets from Space
# 325                    Muppets from Space
# 326                    Muppets from Space
# 380  The Adventures of Elmo in Grouchland
# 381  The Adventures of Elmo in Grouchland
# 382  The Adventures of Elmo in Grouchland
# 458                      The Dark Crystal
# 459                      The Dark Crystal
# 527                The Great Muppet Caper
# 528                The Great Muppet Caper
# 529                The Great Muppet Caper
# 530                The Great Muppet Caper
# 531                The Great Muppet Caper
# 532                The Great Muppet Caper
# 623            The Muppet Christmas Carol
# 624            The Muppet Christmas Carol
# 625            The Muppet Christmas Carol
# 626            The Muppet Christmas Carol
# 627            The Muppet Christmas Carol
# 628            The Muppet Christmas Carol
# 629            The Muppet Christmas Carol
# 741                      The Muppet Movie
# 742                      The Muppet Movie
# 743                      The Muppet Movie
# 744                      The Muppet Movie
# 745                      The Muppet Movie
# 746                      The Muppet Movie
# 747                      The Muppet Movie
# 748                      The Muppet Movie
# 853            The Muppets Take Manhattan
# 854            The Muppets Take Manhattan
# 855            The Muppets Take Manhattan
# 856            The Muppets Take Manhattan
# 857            The Muppets Take Manhattan
# 858            The Muppets Take Manhattan
# 859            The Muppets Take Manhattan
#
#                                            character_y
# 38                                         Mr. Collins
# 39                                          Miss Piggy
# 105                                     Cookie Monster
# 106                                               Bert
# 107                                             Grover
# 224                                         Miss Piggy
# 225                                        Fozzie Bear
# 226                                      Sam the Eagle
# 227                                             Animal
# 323                                         Miss Piggy
# 324                                        Fozzie Bear
# 325                                             Animal
# 326                                      Sam the Eagle
# 380                                               Bert
# 381                                             Grover
# 382                                     Cookie Monster
# 458            Aughra, a Keeper Of Secrets (performer)
# 459                            Chamberlain (performer)
# 527                                         Miss Piggy
# 528                                        Fozzie Bear
# 529                                             Animal
# 530                                      Sam the Eagle
# 531                                             Gramps
# 532                                       Swedish Chef
# 623                       Miss Piggy as Emily Cratchit
# 624                           Fozzie Bear as Fozziewig
# 625  Sam the Eagle as Headmaster of Junior High Gra...
# 626                                             Animal
# 627                                 George the Janitor
# 628                          Horse and Carriage Driver
# 629                                 Vegetable Salesman
# 741                                         Miss Piggy
# 742                                        Fozzie Bear
# 743                                             Animal
# 744                                      Sam the Eagle
# 745                                   Doc Hopper's Men
# 746                                       Marvin Suggs
# 747                           Swedish Chef (assistant)
# 748                                     Motorcycle Guy
# 853                                         Miss Piggy
# 854                                             Fozzie
# 855                                             Animal
# 856                                               Bert
# 857                                     Cookie Monster
# 858                     Ocean Breeze Soap Board Member
# 859                                      Sam the Eagle
